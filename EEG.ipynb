# %%
import mne
import os

# %%
raw= mne.io.read_raw_edf("SC4001E0-PSG.edf",preload=True)
# Out:
# Extracting EDF parameters from C:\Users\NIKHAT PARVEEN\SC4001E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\NIKHAT PARVEEN\AppData\Local\Temp\ipykernel_17068\1265866776.py:1: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw= mne.io.read_raw_edf("SC4001E0-PSG.edf",preload=True)
# C:\Users\NIKHAT PARVEEN\AppData\Local\Temp\ipykernel_17068\1265866776.py:1: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw= mne.io.read_raw_edf("SC4001E0-PSG.edf",preload=True)
# C:\Users\NIKHAT PARVEEN\AppData\Local\Temp\ipykernel_17068\1265866776.py:1: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw= mne.io.read_raw_edf("SC4001E0-PSG.edf",preload=True)
# Reading 0 ... 7949999  =      0.000 ... 79499.990 secs...

# %%
raw.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG Fpz-Cz, EEG Pz-Oz, EOG horizontal, Resp oro-nasal, EMG ...
#  chs: 7 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 50.0 Hz
#  meas_date: 1989-04-24 16:13:00 UTC
#  nchan: 7
#  projs: []
#  sfreq: 100.0 Hz
#  subject_info: <subject_info | his_id: X, sex: 2, first_name: Female, last_name: 33yr>
# >

# %%
print('Number of channels:',len(raw.ch_names))
print('Channels Names:', raw.ch_names)
print('Sampling Frequency:', raw.info['sfreq'])
# Out:
# Number of channels: 7
# Channels Names: ['EEG Fpz-Cz', 'EEG Pz-Oz', 'EOG horizontal', 'Resp oro-nasal', 'EMG submental', 'Temp rectal', 'Event marker']
# Sampling Frequency: 100.0

# %%
import matplotlib.pyplot as plt

# %%
raw.plot(n_channels=7, duration=10, title='EEG Raw Data', show=True)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
